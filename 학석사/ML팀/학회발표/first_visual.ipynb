# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("mobility.xlsx");data
# Out:
#           Date   count  age65up  Delta_count  Omicron_count  Delta_prop  \
# 0   2020-02-15       0        0            0              0         0.0
# 1   2020-02-16       2        2            0              0         0.0
# 2   2020-02-17       0        0            0              0         0.0
# 3   2020-02-18       2        0            0              0         0.0
# 4   2020-02-19      34        5            0              0         0.0
# ..         ...     ...      ...          ...            ...         ...
# 782 2022-04-07  224761    30541            0              0         0.0
# 783 2022-04-08  205302    29193            0              0         0.0
# 784 2022-04-09  185526    29472            0              0         0.0
# 785 2022-04-10  164454    26131            0              0         0.0
# 786 2022-04-11   90907    11630            0              0         0.0
#
#      Omicron_prop  seoul_retail_recreation  seoul_grocery_pharmacy  \
# ...

# %%
data = data[['Date', 'count', 'seoul_retail_recreation', "seoul_grocery_pharmacy", 'seoul_parks', 'seoul_workplaces', 'seoul_residential']]

# %%
data
# Out:
#           Date   count  seoul_retail_recreation  seoul_grocery_pharmacy  \
# 0   2020-02-15       0                       -4                       0
# 1   2020-02-16       2                      -11                       0
# 2   2020-02-17       0                       -7                      -6
# 3   2020-02-18       2                       -1                      -3
# 4   2020-02-19      34                       -5                      -1
# ..         ...     ...                      ...                     ...
# 782 2022-04-07  224761                       -6                       8
# 783 2022-04-08  205302                       -5                      14
# 784 2022-04-09  185526                        0                      18
# 785 2022-04-10  164454                        9                      14
# 786 2022-04-11   90907                        4                      22
#
#      seoul_parks  seoul_workplaces  seoul_residential
# ...

# %%
data.describe()
# Out:
#                count  seoul_retail_recreation  seoul_grocery_pharmacy  \
# count     787.000000               787.000000              787.000000
# mean    19560.321474                -5.101652               14.828463
# std     71211.166727                12.382571               13.307378
# min         0.000000               -47.000000              -18.000000
# 25%        95.000000               -13.000000                6.000000
# 50%       522.000000                -4.000000               14.000000
# 75%      1818.500000                 4.000000               24.000000
# max    621159.000000                23.000000               94.000000
#
#        seoul_parks  seoul_workplaces  seoul_residential
# count   787.000000        787.000000         787.000000
# mean     29.132147         -6.260483           4.209657
# std      28.902580         12.939161           3.863841
# min     -42.000000        -84.000000          -3.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787 entries, 0 to 786
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     787 non-null    datetime64[ns]
#  1   count                    787 non-null    int64
#  2   seoul_retail_recreation  787 non-null    int64
#  3   seoul_grocery_pharmacy   787 non-null    int64
#  4   seoul_parks              787 non-null    int64
#  5   seoul_workplaces         787 non-null    int64
#  6   seoul_residential        787 non-null    int64
# dtypes: datetime64[ns](1), int64(6)
# memory usage: 43.2 KB

# %%
plt.figure(figsize = (20, 16))
plt.plot(data['Date'], data['count'], color = 'burlywood', label = 'count')
plt.xticks(fontsize = 9, rotation = 90)
plt.title('total count')
plt.ylabel('count')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.plot(data['Date'], data['seoul_retail_recreation'], color = 'burlywood', label = 'count')
plt.xticks(fontsize = 9, rotation = 90)
plt.title('seoul_retail_recreation')
plt.ylabel('count')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.plot(data['Date'], data['seoul_grocery_pharmacy'], color = 'burlywood', label = 'count')
plt.xticks(fontsize = 9, rotation = 90)
plt.title('seoul_grocery_pharmacy')
plt.ylabel('count')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.plot(data['Date'], data['seoul_parks'], color = 'burlywood', label = 'count')
plt.xticks(fontsize = 9, rotation = 90)
plt.title('seoul_parks')
plt.ylabel('count')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.plot(data['Date'], data['seoul_workplaces'], color = 'burlywood', label = 'count')
plt.xticks(fontsize = 9, rotation = 90)
plt.title('seoul_workplaces')
plt.ylabel('count')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.plot(data['Date'], data['seoul_residential'], color = 'burlywood', label = 'count')
plt.xticks(fontsize = 9, rotation = 90)
plt.title('seoul_residential')
plt.ylabel('count')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['Date'], data['seoul_grocery_pharmacy'] , s = 5, color = 'purple', alpha = 0.6, label = 'grocery_pharmacy')
plt.scatter(data['Date'], data['seoul_parks'] , s = 5, color = 'orange', alpha = 0.6, label = 'parks')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['Date'], data['seoul_grocery_pharmacy'] , s = 5, color = 'purple', alpha = 0.6, label = 'grocery_pharmacy')
plt.scatter(data['Date'], data['seoul_workplaces'] , s = 5, color = 'orange', alpha = 0.6, label = 'workplaces')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['Date'], data['seoul_grocery_pharmacy'] , s = 5, color = 'purple', alpha = 0.6, label = 'grocery_pharmacy')
plt.scatter(data['Date'], data['seoul_residential'] , s = 5, color = 'orange', alpha = 0.6, label = 'residential')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_grocery_pharmacy'], data['seoul_parks'], s = 5, alpha = 0.6)
plt.xlabel("pharmacy")
plt.ylabel("parks")
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_grocery_pharmacy'], data['seoul_workplaces'], s = 5, alpha = 0.6)
plt.xlabel("pharmacy")
plt.ylabel("workplaces")
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_grocery_pharmacy'], data['seoul_residential'], s = 5, alpha = 0.6)
plt.xlabel("pharmacy")
plt.ylabel("residential")
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_retail_recreation'], data['seoul_grocery_pharmacy'], s = 5, alpha = 0.6)
plt.xlabel("retail_recreation")
plt.ylabel("grocery_pharmacy")
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_retail_recreation'], data['seoul_parks'], s = 5, alpha = 0.6)
plt.xlabel("retail_recreation")
plt.ylabel("parks")
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_retail_recreation'], data['seoul_workplaces'], s = 5, alpha = 0.6)
plt.xlabel("retail_recreation")
plt.ylabel("workplaces")
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_retail_recreation'], data['seoul_residential'], s = 5, alpha = 0.6)
plt.xlabel("retail_recreation")
plt.ylabel("residential")
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_parks'], data['seoul_workplaces'], s = 5, alpha = 0.6)
plt.xlabel("parks")
plt.ylabel("workplaces")
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_parks'], data['seoul_residential'], s = 5, alpha = 0.6)
plt.xlabel("parks")
plt.ylabel("residential")
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.scatter(data['seoul_workplaces'], data['seoul_residential'], s = 5, alpha = 0.6)
plt.xlabel("workplaces")
plt.ylabel("residential")
plt.show()
