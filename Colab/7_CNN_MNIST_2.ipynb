# %%
#실행하시기 전에 속도를 높일려면 [런타임]-[런타임 유형 변경]-[하드웨어 가속기 : GPU]를 선택하시고 저장하시면 됩니다. 

import tensorflow as tf
import matplotlib.pyplot as plt

#Fashion MNIST dataset
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_X, train_Y), (test_X, test_Y) = fashion_mnist.load_data()
train_X = train_X / 255
test_X = test_X / 255

train_X = train_X.reshape(-1, 28, 28, 1)
test_X = test_X.reshape(-1, 28, 28, 1)

print('After reshape : ', train_X.shape, test_X.shape)

# figure show
plt.figure(figsize=(10, 10))
for c in range(16):  
    plt.subplot(4,4,c+1)
    plt.imshow(train_X[c].reshape(28,28), cmap='gray')
    
plt.show()

# 부류 출력 (0:티셔츠, 1:바지, 2:스웨터, 3:드레스, 4:코드, 5:샌들, 6:셔츠, 7:운동화, 8:가방, 9:부츠)
print(train_Y[:16])

# !nvidia-smi
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# After reshape :  (60000, 28, 28, 1) (10000, 28, 28, 1)
# [9 0 0 3 0 2 7 2 5 5 0 9 5 5 7 9]
# Fri Dec  9 13:02:16 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#Fashion MNIST CNN Model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=16),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=32),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()

history = model.fit(train_X, train_Y, epochs=20, validation_split=0.25)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=1)
print("\n Test Accuracy: %.4f" % (model.evaluate(test_X, test_Y, verbose=1)[1]))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 16)        160
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 32)        4640
#
#  conv2d_2 (Conv2D)           (None, 22, 22, 64)        18496
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,989,642
# Trainable params: 3,989,642
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1407/1407 [==============================] - 20s 6ms/step - loss: 0.4616 - accuracy: 0.8361 - val_loss: 0.3704 - val_accuracy: 0.8677
# Epoch 2/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.3394 - accuracy: 0.8753 - val_loss: 0.3593 - val_accuracy: 0.8716
# Epoch 3/20
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.2846 - accuracy: 0.8946 - val_loss: 0.3698 - val_accuracy: 0.8763
# Epoch 4/20
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.2374 - accuracy: 0.9116 - val_loss: 0.3731 - val_accuracy: 0.8735
# Epoch 5/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.2110 - accuracy: 0.9225 - val_loss: 0.4324 - val_accuracy: 0.8638
# Epoch 6/20
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1858 - accuracy: 0.9315 - val_loss: 0.4378 - val_accuracy: 0.8722
# Epoch 7/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1614 - accuracy: 0.9400 - val_loss: 0.5318 - val_accuracy: 0.8695
# Epoch 8/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1539 - accuracy: 0.9442 - val_loss: 0.5161 - val_accuracy: 0.8723
# Epoch 9/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1309 - accuracy: 0.9514 - val_loss: 0.6069 - val_accuracy: 0.8636
# Epoch 10/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1288 - accuracy: 0.9535 - val_loss: 0.6328 - val_accuracy: 0.8698
# Epoch 11/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1148 - accuracy: 0.9582 - val_loss: 0.6987 - val_accuracy: 0.8672
# Epoch 12/20
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.1055 - accuracy: 0.9611 - val_loss: 0.6680 - val_accuracy: 0.8673
# Epoch 13/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0997 - accuracy: 0.9640 - val_loss: 0.7516 - val_accuracy: 0.8657
# Epoch 14/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0893 - accuracy: 0.9675 - val_loss: 0.8563 - val_accuracy: 0.8611
# Epoch 15/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0892 - accuracy: 0.9685 - val_loss: 0.8847 - val_accuracy: 0.8666
# Epoch 16/20
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.0867 - accuracy: 0.9705 - val_loss: 0.8635 - val_accuracy: 0.8691
# Epoch 17/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0833 - accuracy: 0.9713 - val_loss: 0.9936 - val_accuracy: 0.8623
# Epoch 18/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0715 - accuracy: 0.9758 - val_loss: 0.9790 - val_accuracy: 0.8635
# Epoch 19/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.0744 - accuracy: 0.9737 - val_loss: 1.1323 - val_accuracy: 0.8575
# Epoch 20/20
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.0747 - accuracy: 0.9752 - val_loss: 1.0964 - val_accuracy: 0.8659
# 313/313 [==============================] - 1s 3ms/step - loss: 1.0845 - accuracy: 0.8657
# 313/313 [==============================] - 1s 3ms/step - loss: 1.0845 - accuracy: 0.8657
#
#  Test Accuracy: 0.8657

# %%
# Fashion MNIST CNN Model - Add MaxPool, Dropout
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()

history = model.fit(train_X, train_Y, epochs=20, validation_split=0.25)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.show()

print(model.evaluate(test_X, test_Y, verbose=1)[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_2 (Dense)             (None, 128)               147584
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 241,546
# Trainable params: 241,546
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.5340 - accuracy: 0.8050 - val_loss: 0.3769 - val_accuracy: 0.8583
# Epoch 2/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.3603 - accuracy: 0.8690 - val_loss: 0.3409 - val_accuracy: 0.8754
# Epoch 3/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.3202 - accuracy: 0.8846 - val_loss: 0.3185 - val_accuracy: 0.8823
# Epoch 4/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2904 - accuracy: 0.8930 - val_loss: 0.3086 - val_accuracy: 0.8864
# Epoch 5/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2681 - accuracy: 0.9035 - val_loss: 0.3035 - val_accuracy: 0.8870
# Epoch 6/20
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.2521 - accuracy: 0.9092 - val_loss: 0.2967 - val_accuracy: 0.8933
# Epoch 7/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2358 - accuracy: 0.9115 - val_loss: 0.3080 - val_accuracy: 0.8953
# Epoch 8/20
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.2217 - accuracy: 0.9178 - val_loss: 0.3044 - val_accuracy: 0.8952
# Epoch 9/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2168 - accuracy: 0.9213 - val_loss: 0.3071 - val_accuracy: 0.8999
# Epoch 10/20
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.2025 - accuracy: 0.9247 - val_loss: 0.3192 - val_accuracy: 0.8972
# Epoch 11/20
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1888 - accuracy: 0.9288 - val_loss: 0.3282 - val_accuracy: 0.8988
# Epoch 12/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1819 - accuracy: 0.9321 - val_loss: 0.3352 - val_accuracy: 0.8976
# Epoch 13/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1767 - accuracy: 0.9345 - val_loss: 0.3369 - val_accuracy: 0.8975
# Epoch 14/20
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1738 - accuracy: 0.9347 - val_loss: 0.3572 - val_accuracy: 0.8954
# Epoch 15/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1671 - accuracy: 0.9369 - val_loss: 0.3660 - val_accuracy: 0.8947
# Epoch 16/20
# 1407/1407 [==============================] - 8s 6ms/step - loss: 0.1644 - accuracy: 0.9392 - val_loss: 0.3705 - val_accuracy: 0.8998
# Epoch 17/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1576 - accuracy: 0.9422 - val_loss: 0.3647 - val_accuracy: 0.8879
# Epoch 18/20
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1544 - accuracy: 0.9422 - val_loss: 0.3944 - val_accuracy: 0.8971
# Epoch 19/20
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1506 - accuracy: 0.9444 - val_loss: 0.4214 - val_accuracy: 0.8917
# Epoch 20/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1456 - accuracy: 0.9454 - val_loss: 0.4142 - val_accuracy: 0.8991
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3944 - accuracy: 0.8948
# 0.8948000073432922

# %%
# Fashion MNIST CNN Model - VGGNet style
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='valid', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()

history = model.fit(train_X, train_Y, epochs=20, validation_split=0.25)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.show()

print(model.evaluate(test_X, test_Y, verbose=1)[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)        320
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 128)       73856
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten_2 (Flatten)         (None, 9216)              0
#
#  dense_4 (Dense)             (None, 512)               4719104
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 5,240,842
# Trainable params: 5,240,842
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
#  483/1407 [=========>....................] - ETA: 7s - loss: 0.8603 - accuracy: 0.6860
